# %% [markdown]
# <a href="https://colab.research.google.com/github/tlokender61/data-science/blob/main/Text_Cleaning_%26_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS as stopwords
import pandas as pd
import numpy as np
df=pd.read_csv('https://raw.githubusercontent.com/laxmimerit/twitter-data/master/twitter4000.csv')
df
# Out:
#                                                  twitts  sentiment
# 0     is bored and wants to watch a movie  any sugge...          0
# 1              back in miami.  waiting to unboard ship           0
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                     ughhh i am so tired  blahhhhhhhhh          0
# 4     @mandagoforth me bad! It's funny though. Zacha...          0
# ...                                                 ...        ...
# 3995                                  i just graduated           1
# 3996          Templating works; it all has to be done            1
# 3997                   mommy just brought me starbucks           1
# 3998  @omarepps watching you on a House re-run...lov...          1
# 3999  Thanks for trying to make me smile I'll make y...          1
#
# [4000 rows x 2 columns]

# %%
def word_count(x):
  return len(x.split())
  
df['word_count']=df['twitts'].apply(lambda x:word_count(str(x)))
df[df['word_count']==1]
# Out:
#                                twitts  sentiment  word_count
# 385                         homework           0           1
# 691                         @ekrelly           0           1
# 1124                    disappointed           0           1
# 1286                 @officialmgnfox           0           1
# 1325                        headache           0           1
# 1897                      @MCRmuffin           0           1
# 2542                      Graduated!           1           1
# 2947                         reading           1           1
# 3176                    @omeirdeleon           1           1
# 3470  www.myspace.com/myfinalthought           1           1
# 3966                        @gethyp3           1           1

# %%
text='there is a space'
def char_count(val):
  s = val.split()
  val=''.join(s)
  return  len(val)
  
ignore_space(text)
df['char_count']=df['twitts'].apply(lambda x:char_count(str(x)))

# %%
def char_avg_count(x):
  return (char_count(x)/word_count(x))

df['char_avg_count']=df['twitts'].apply(lambda x: char_avg_count(str(x)))

# %%
text='this is a stopword'
len([t for t in text.split() if t in stopwords])
# Out:
# 3

# %%
df['stop_words_len']=df['twitts'].apply(lambda x: len([t for t in str(x).split() if t in stopwords]))

# %% [markdown]
# Count #hashtags and @Mentions

# %%
x='this is a #hashtag and this is a @mention'
[t for t in x.split() if t.startswith('#')]
df['hastag_count']=df['twitts'].apply(lambda x:len([t for t in str(x).split() if t.startswith('#')]))
df['at_count']=df['twitts'].apply(lambda x:len([t for t in str(x).split() if t.startswith('@')]))

# %% [markdown]
# If numeric digits are present in twitts

# %%
x='i have 12 digits prensent'
df['numeric_count']=df['twitts'].apply(lambda x: len([t for t in str(x).split() if t.isdigit()]))
df[df['numeric_count']>1]
# Out:
#                                                  twitts  ...  numeric_count
# 53    @Gen215 ROFL following Jesus! Found 1 th othr ...  ...              3
# 125        @MasterAwesome 23 almost 24   im an old lady  ...              2
# 174   ohhh 2 write bak 2 ppl u hav 2 put their names...  ...              4
# 209   AT&amp;T: &quot;you have 4 bars of 3G. oh wait...  ...              2
# 278   Listenin 2 a bunch of janet's old slow songs w...  ...              2
# 440   Reeling from the news that an 11 and a 10 year...  ...              2
# 448   I'm bout 2go smoke. I'm not an addict. I just ...  ...              2
# 462   10 days to recover from ligament damage (from ...  ...              2
# 516   i was goin 2 welcome my 160th follower, only 2...  ...              2
# 535   @newsboys: nice how was the concert in Michiga...  ...              2
# 591   just thought about how unfair 3 ppl have been ...  ...              2
# ...

# %% [markdown]
# UPPER case words count

# %%
df['upper_count']=df['twitts'].apply(lambda x: len([t for t in str(x).split() if t.isupper()]))

# %% [markdown]
# Contraction to Expansion
